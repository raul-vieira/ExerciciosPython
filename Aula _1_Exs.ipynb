# %%
"""""Disciplina: Introdução à Python - Aula 1 - Exercícios.
Ex.1: Crie um algoritmo que imprima o seu nome. Salve o arquivo com o
nome ex1.py

Ex.2: Crie um algoritmo que imprima o seu nome 1000 vezes. Salve o
arquivo com o nome ex2.py

Ex.3: Crie um algoritmo que a partir de uma variável criada no código,
imprima o texto "o valor é maior que 10" caso isso seja verdade,
senão imprima "o valor é menor que 10". Salve o arquivo com o
nome ex3.py

Ex.4: Crie um algoritmo que a partir de uma variável criada no código,
imprima o texto "o valor é maior ou igual a 10" caso isso seja
verdade, senão imprima "o valor não é maior ou igual a 10". Salve o
arquivo com o nome ex4.py.

Ex.5: Crie um algoritmo que a partir de uma variável criada no código,
verifique se esse valor é positivo, negativo ou igual a zero. Imprima na
tela: "Valor Positivo"; "Valor Negativo", "Igual a Zero";. Salve o arquivo
com o nome ex5.py

# %%
# Ex.1
print("Raul Vieira!")
# Out:
# Raul Vieira!

# %%
# Ex.2
for i in range(0,1001):
    print("Raul Vieira!")
# Out:
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# Raul Vieira!
# ...

# %%
# Ex.3
a = float(input("Digite um valor: "))
if a > 10:
    print("O valor é maior que 10")
elif a == 10:
    print("O valor é = 10")
else:
    print("O valor é menor que 10")
# Out:
# Digite um valor: 20
# O valor é maior que 10

# %%
# Ex.4
a = float(input("Digite um valor: "))
if a > 10:
    print("O valor é maior que 10")
else:
    print("O valor não é maior que 10")
# Out:
# Digite um valor: 5
# O valor não é maior que 10

# %%
# Ex.5
a = float(input("Digite um valor: "))
if a > 0:
    print("Valor Positivo")
elif a == 0:
    print("Valor igual a 0")
else:
    print("Valor Negativo")
# Out:
# Digite um valor: 0
# Valor igual a 0
